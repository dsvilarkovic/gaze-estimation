# %%
# !pip install torch torchvision

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt 

from scipy.io import loadmat
import numpy as np
import torch.utils.data
from torchvision import transforms, datasets
from torch.utils.data import Dataset, DataLoader
from scipy import misc
import matplotlib.patches as patches
from datetime import datetime
from scipy.misc import imshow
import model_code.multi_modal_nn as mmnn
from model_code.face_landmark_dataset import FaceLandmarksDataset
import model_code.test as test
import model_code.train as train
 

feature_size = 136
output_size = 1
image_dim = 108
im_height = 60
im_width = 108

# %%
def extract_data(indices, suffix = '', include_pos = True):
  ftrs = torch.Tensor()
  ftrs = ftrs.type(torch.cuda.FloatTensor)  
  gz = torch.Tensor()
  gz = gz.type(torch.cuda.FloatTensor) 
    
  eye_reg = torch.Tensor()
  eye_reg = eye_reg.type(torch.cuda.IntTensor)
    
    
  img_loc = np.asarray([])
#   img_loc = img_loc.type(torch.cuda.FloatTensor) 
  
  for index in indices:
    data = loadmat(str(index) + suffix + '_lmarks_location_eye.mat')
    
    #Landmark features
    ftrs_single = torch.from_numpy(data['ftrs'])
    
    
    ftrs_single = ftrs_single.type(torch.cuda.FloatTensor)  

    
    ftrs = torch.cat((ftrs, ftrs_single))
    
    #Gaze features

    gz_single = torch.from_numpy(data['gz'])
    gz_single = gz_single.type(torch.cuda.FloatTensor)  

    gz_single = torch.t(gz_single)

    gz = torch.cat((gz, gz_single))
    
    
    #Eye regions should be n X 4 size
    
    eye_reg_single = torch.from_numpy(data['eye_reg'])
    eye_reg_single = eye_reg_single.type(torch.cuda.IntTensor)
    
    
    eye_reg = torch.cat((eye_reg, eye_reg_single))
    
    
    #Get image location
    
    img_loc_single = data['location']
        
    img_loc = np.concatenate((img_loc, img_loc_single))
    
  return(ftrs, gz, eye_reg, img_loc)

# %%
def test_model(net, test_face_landmarks_dataset, batch_size = 128):
  net.eval()
#   y_total = torch.Tensor().cuda()
#   y_hat_total = torch.Tensor().cuda()

  accuracies = []

  testloader = torch.utils.data.DataLoader(dataset=test_face_landmarks_dataset , batch_size=batch_size, shuffle=True)
  
  then = datetime.now()

  for i, (train_batch) in enumerate(testloader):

      #calculating time
      now  = datetime.now()  
      duration = now - then 

      seconds = duration.total_seconds()
      minutes = divmod(seconds, 60)[0]


      print(datetime.now().time())
      print('Time for testing passed %d minutes and %d seconds' % (minutes, seconds))
      #for measuring starting time
      then = datetime.now()


      (x_batch, y_batch) = train_batch
      optimizer.zero_grad()
      yhat = torch.Tensor()
      yhat = yhat.type(torch.cuda.FloatTensor)  


      yhat = net(x_batch) 


      yhat = yhat > 0.5
      accuracy = accuracy_score(yhat.cpu().numpy(), y_batch.cpu().numpy())



      print('This batch accuracy is %f %%' % (100.0 * accuracy) )
      print('Completed %d/%d  %f %%' % (batch_size*(i + 1), len(test_face_landmarks_dataset) , 100.0 * batch_size*(i + 1) / len(test_face_landmarks_dataset)))

      yhat = ftrs.type(torch.cuda.FloatTensor)  

    
      accuracies.append(accuracy)
  

  return (accuracies)

# %%
test_indices = [404,407,410]
train_indices = [401,402,403,405]


ftrs = torch.Tensor()
gz = torch.Tensor()

(ftrs, gz, eye_reg, img_loc) = extract_data(train_indices)

# %%
#Take out test data

test_ftrs = torch.Tensor().cuda()
test_gz = torch.Tensor().cuda()

(test_ftrs, test_gz, test_eye_reg, test_img_loc) = extract_data(test_indices)

print(test_gz.shape)
print(test_ftrs.shape)
# Out:
# torch.Size([263857, 1])
# torch.Size([263857, 136])

# %%
(net,optimizer, scheduler) = mmnn.get_net_instance()
up = 0
down= 100
face_landmarks_dataset = FaceLandmarksDataset(ftrs = ftrs[up:down], eye_regions= eye_reg.cuda()[up:down], locations=img_loc[up:down],  gz = gz.cuda()[up:down], train_transforms=None, test_transforms=None)

# %%
x_test = test_ftrs
y_test = test_gz

test_face_landmarks_dataset = FaceLandmarksDataset(ftrs = test_ftrs, eye_regions=test_eye_reg.cuda(), locations=test_img_loc,  gz = test_gz.cuda(), train_transforms=None, test_transforms=None, load_type='test')

(net,optimizer, scheduler) = mmnn.get_net_instance()

# net.load_state_dict(torch.load('model_code/log_results/multimodal_model_14_64.py'))

# %%
import torch.onnx

train_id = 20
#18952 = 56x112x3 + 136
dummy_input = torch.randn(1, 18952, device='cuda')
print(net)
net.load_state_dict(torch.load('model_code/log_results/24/models/multimodal_model_24_256_epoch_0.py'))

torch.onnx.export(net,dummy_input, "model_20.onnx")
# Out:
# MultiModalNetwork(
#   (landmarkUnit): LandmarkUnit(
#     (relu): ReLU()
#     (fc1): Linear(in_features=136, out_features=68, bias=True)
#     (fc1_bn): BatchNorm1d(68, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (fc2): Linear(in_features=68, out_features=68, bias=True)
#     (fc2_bn): BatchNorm1d(68, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (fc3): Linear(in_features=68, out_features=34, bias=True)
#     (fc3_bn): BatchNorm1d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (fc5): Linear(in_features=34, out_features=34, bias=True)
#     (fc5_bn): BatchNorm1d(34, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (imageUnit): ImageUnit(
#     (conv1): Conv2d(3, 32, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2))
#     (conv1_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU()
#     (conv2): Conv2d(32, 32, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2))
#     (conv2_bn): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU()
#     (pool1): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (conv3): Conv2d(32, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2))
#     (conv3_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu3): ReLU()
#     (conv4): Conv2d(64, 64, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2))
#     (conv4_bn): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu4): ReLU()
#     (pool2): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (conv5): Conv2d(64, 128, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2))
#     (conv5_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu5): ReLU()
#     (conv6): Conv2d(128, 128, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2))
#     (conv6_bn): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu6): ReLU()
#     (pool3): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (conv7): Conv2d(128, 256, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2))
#     (conv7_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu7): ReLU()
#     (conv8): Conv2d(256, 256, kernel_size=(3, 5), stride=(1, 1), padding=(1, 2))
#     (conv8_bn): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu8): ReLU()
#     (pool4): MaxPool2d(kernel_size=(2, 2), stride=(2, 2), padding=0, dilation=1, ceil_mode=False)
#     (fc): Linear(in_features=5376, out_features=1024, bias=True)
#     (fc_bn): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (out): Sigmoid()
#     (dropout02): Dropout(p=0.2)
#     (dropout05): Dropout(p=0.5)
#   )
#   (fc1): Linear(in_features=1058, out_features=264, bias=True)
#   (fc1_bn): BatchNorm1d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=264, out_features=66, bias=True)
#   (fc2_bn): BatchNorm1d(66, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=66, out_features=1, bias=True)
#   (fc3_bn): BatchNorm1d(1, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (dropout): Dropout(p=0.5)
#   (out): Sigmoid()
# )
# model_code/multi_modal_nn.py:45: TracerWarning: There are 4 live references to the data region being modified when tracing in-place operator copy_ (possibly due to an assignment). This might cause the trace to be incorrect, because all other views that also reference this data will not reflect this change in the trace! On the other hand, if all other views use the same memory chunk, but are disjoint (e.g. are outputs of torch.split), this might still be safe.
#   x[0:135:2] = x[0:135:2] / 608.0
# model_code/multi_modal_nn.py:46: TracerWarning: There are 4 live references to the data region being modified when tracing in-place operator copy_ (possibly due to an assignment). This might cause the trace to be incorrect, because all other views that also reference this data will not reflect this change in the trace! On the other hand, if all other views use the same memory chunk, but are disjoint (e.g. are outputs of torch.split), this might still be safe.
#   x[1:136:2] = x[1:136:2] / 342.0
# model_code/multi_modal_nn.py:231: TracerWarning: Converting a tensor to a Python integer might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   print(imageUnitOut.shape, landmarksUnitOut.shape)
# (torch.Size([1, 1024]), torch.Size([1, 34]))

# %%
batch_size = 32

output_file = 'model_code/log_results/proba.txt' 
output_model_file = 'model_code/log_results/proba'

net = train.train_model(scheduler,optimizer,output_model_file, net, face_landmarks_dataset , 30, 1, False, batch_size = batch_size, output_file = output_file, train_id = 0)
# Out:
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([4, 1024]), torch.Size([4, 34]))
# Test size is 6000
# 21:06:38.044312
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.390625 %
# Completed 256/6000  4.266667 %
# Total correct predicted number is 193 out of 256
# 21:06:38.422132
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 74.218750 %
# Completed 512/6000  8.533333 %
# Total correct predicted number is 190 out of 256
# 21:06:38.798786
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.828125 %
# Completed 768/6000  12.800000 %
# Total correct predicted number is 189 out of 256
# 21:06:39.181416
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.875000 %
# Completed 1024/6000  17.066667 %
# Total correct predicted number is 184 out of 256
# 21:06:39.558742
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.390625 %
# Completed 1280/6000  21.333333 %
# Total correct predicted number is 193 out of 256
# 21:06:39.933906
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.093750 %
# Completed 1536/6000  25.600000 %
# Total correct predicted number is 182 out of 256
# 21:06:40.324480
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.390625 %
# Completed 1792/6000  29.866667 %
# Total correct predicted number is 193 out of 256
# 21:06:40.702984
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 70.703125 %
# Completed 2048/6000  34.133333 %
# Total correct predicted number is 181 out of 256
# 21:06:41.079274
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 70.312500 %
# Completed 2304/6000  38.400000 %
# Total correct predicted number is 180 out of 256
# 21:06:41.455849
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.265625 %
# Completed 2560/6000  42.666667 %
# Total correct predicted number is 185 out of 256
# 21:06:41.835267
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.390625 %
# Completed 2816/6000  46.933333 %
# Total correct predicted number is 193 out of 256
# 21:06:42.216287
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 80.468750 %
# Completed 3072/6000  51.200000 %
# Total correct predicted number is 206 out of 256
# 21:06:42.596031
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 69.921875 %
# Completed 3328/6000  55.466667 %
# Total correct predicted number is 179 out of 256
# 21:06:42.974262
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.390625 %
# Completed 3584/6000  59.733333 %
# Total correct predicted number is 193 out of 256
# 21:06:43.375642
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 67.968750 %
# Completed 3840/6000  64.000000 %
# Total correct predicted number is 174 out of 256
# 21:06:43.752892
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 70.703125 %
# Completed 4096/6000  68.266667 %
# Total correct predicted number is 181 out of 256
# 21:06:44.132011
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 76.953125 %
# Completed 4352/6000  72.533333 %
# Total correct predicted number is 197 out of 256
# 21:06:44.514002
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.781250 %
# Completed 4608/6000  76.800000 %
# Total correct predicted number is 194 out of 256
# 21:06:44.893240
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 76.171875 %
# Completed 4864/6000  81.066667 %
# Total correct predicted number is 195 out of 256
# 21:06:45.274130
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 79.687500 %
# Completed 5120/6000  85.333333 %
# Total correct predicted number is 204 out of 256
# 21:06:45.653727
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 69.531250 %
# Completed 5376/6000  89.600000 %
# Total correct predicted number is 178 out of 256
# 21:06:46.033433
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 70.703125 %
# Completed 5632/6000  93.866667 %
# Total correct predicted number is 181 out of 256
# 21:06:46.414892
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 74.218750 %
# Completed 5888/6000  98.133333 %
# Total correct predicted number is 190 out of 256
# 21:06:46.589385
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([112, 1024]), torch.Size([112, 34]))
# This batch accuracy is 63.392857 %
# Completed 6144/6000  102.400000 %
# Total correct predicted number is 71 out of 256
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([4, 1024]), torch.Size([4, 34]))
# Test size is 6000
# 21:06:48.705699
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.828125 %
# Completed 256/6000  4.266667 %
# Total correct predicted number is 189 out of 256
# 21:06:49.087103
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.828125 %
# Completed 512/6000  8.533333 %
# Total correct predicted number is 189 out of 256
# 21:06:49.467769
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.437500 %
# Completed 768/6000  12.800000 %
# Total correct predicted number is 188 out of 256
# 21:06:49.849337
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.656250 %
# Completed 1024/6000  17.066667 %
# Total correct predicted number is 186 out of 256
# 21:06:50.231357
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.046875 %
# Completed 1280/6000  21.333333 %
# Total correct predicted number is 187 out of 256
# 21:06:50.613834
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.265625 %
# Completed 1536/6000  25.600000 %
# Total correct predicted number is 185 out of 256
# 21:06:50.995243
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 78.515625 %
# Completed 1792/6000  29.866667 %
# Total correct predicted number is 201 out of 256
# 21:06:51.376537
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.828125 %
# Completed 2048/6000  34.133333 %
# Total correct predicted number is 189 out of 256
# 21:06:51.751226
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.000000 %
# Completed 2304/6000  38.400000 %
# Total correct predicted number is 192 out of 256
# 21:06:52.128910
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.828125 %
# Completed 2560/6000  42.666667 %
# Total correct predicted number is 189 out of 256
# 21:06:52.511818
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.000000 %
# Completed 2816/6000  46.933333 %
# Total correct predicted number is 192 out of 256
# 21:06:52.890818
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.484375 %
# Completed 3072/6000  51.200000 %
# Total correct predicted number is 183 out of 256
# 21:06:53.271641
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 74.609375 %
# Completed 3328/6000  55.466667 %
# Total correct predicted number is 191 out of 256
# 21:06:53.653943
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.656250 %
# Completed 3584/6000  59.733333 %
# Total correct predicted number is 186 out of 256
# 21:06:54.034244
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.781250 %
# Completed 3840/6000  64.000000 %
# Total correct predicted number is 194 out of 256
# 21:06:54.415872
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 69.921875 %
# Completed 4096/6000  68.266667 %
# Total correct predicted number is 179 out of 256
# 21:06:54.794406
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 74.609375 %
# Completed 4352/6000  72.533333 %
# Total correct predicted number is 191 out of 256
# 21:06:55.176333
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.046875 %
# Completed 4608/6000  76.800000 %
# Total correct predicted number is 187 out of 256
# 21:06:55.555793
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.875000 %
# Completed 4864/6000  81.066667 %
# Total correct predicted number is 184 out of 256
# 21:06:55.938490
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.046875 %
# Completed 5120/6000  85.333333 %
# Total correct predicted number is 187 out of 256
# 21:06:56.320739
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.046875 %
# Completed 5376/6000  89.600000 %
# Total correct predicted number is 187 out of 256
# 21:06:56.698247
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.093750 %
# Completed 5632/6000  93.866667 %
# Total correct predicted number is 182 out of 256
# 21:06:57.074851
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.828125 %
# Completed 5888/6000  98.133333 %
# Total correct predicted number is 189 out of 256
# 21:06:57.251747
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([112, 1024]), torch.Size([112, 34]))
# This batch accuracy is 70.535714 %
# Completed 6144/6000  102.400000 %
# Total correct predicted number is 79 out of 256
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([4, 1024]), torch.Size([4, 34]))
# Test size is 6000
# 21:06:58.952592
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.093750 %
# Completed 256/6000  4.266667 %
# Total correct predicted number is 182 out of 256
# 21:06:59.334366
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.000000 %
# Completed 512/6000  8.533333 %
# Total correct predicted number is 192 out of 256
# 21:06:59.716529
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 78.125000 %
# Completed 768/6000  12.800000 %
# Total correct predicted number is 200 out of 256
# 21:07:00.098089
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 69.531250 %
# Completed 1024/6000  17.066667 %
# Total correct predicted number is 178 out of 256
# 21:07:00.478448
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 78.125000 %
# Completed 1280/6000  21.333333 %
# Total correct predicted number is 200 out of 256
# 21:07:00.861029
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.265625 %
# Completed 1536/6000  25.600000 %
# Total correct predicted number is 185 out of 256
# 21:07:01.242378
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.828125 %
# Completed 1792/6000  29.866667 %
# Total correct predicted number is 189 out of 256
# 21:07:01.623172
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 70.703125 %
# Completed 2048/6000  34.133333 %
# Total correct predicted number is 181 out of 256
# 21:07:02.000707
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.656250 %
# Completed 2304/6000  38.400000 %
# Total correct predicted number is 186 out of 256
# 21:07:02.377654
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.046875 %
# Completed 2560/6000  42.666667 %
# Total correct predicted number is 187 out of 256
# 21:07:02.759751
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 74.218750 %
# Completed 2816/6000  46.933333 %
# Total correct predicted number is 190 out of 256
# 21:07:03.141774
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 78.125000 %
# Completed 3072/6000  51.200000 %
# Total correct predicted number is 200 out of 256
# 21:07:03.523982
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.656250 %
# Completed 3328/6000  55.466667 %
# Total correct predicted number is 186 out of 256
# 21:07:03.905618
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 69.531250 %
# Completed 3584/6000  59.733333 %
# Total correct predicted number is 178 out of 256
# 21:07:04.294861
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.046875 %
# Completed 3840/6000  64.000000 %
# Total correct predicted number is 187 out of 256
# 21:07:04.675696
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.875000 %
# Completed 4096/6000  68.266667 %
# Total correct predicted number is 184 out of 256
# 21:07:05.054447
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.046875 %
# Completed 4352/6000  72.533333 %
# Total correct predicted number is 187 out of 256
# 21:07:05.436164
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.046875 %
# Completed 4608/6000  76.800000 %
# Total correct predicted number is 187 out of 256
# 21:07:05.818352
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.000000 %
# Completed 4864/6000  81.066667 %
# Total correct predicted number is 192 out of 256
# 21:07:06.200495
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.656250 %
# Completed 5120/6000  85.333333 %
# Total correct predicted number is 186 out of 256
# 21:07:06.575219
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 74.218750 %
# Completed 5376/6000  89.600000 %
# Total correct predicted number is 190 out of 256
# 21:07:06.956058
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.484375 %
# Completed 5632/6000  93.866667 %
# Total correct predicted number is 183 out of 256
# 21:07:07.337700
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 73.437500 %
# Completed 5888/6000  98.133333 %
# Total correct predicted number is 188 out of 256
# 21:07:07.513185
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([112, 1024]), torch.Size([112, 34]))
# This batch accuracy is 78.571429 %
# Completed 6144/6000  102.400000 %
# Total correct predicted number is 88 out of 256
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([32, 1024]), torch.Size([32, 34]))
# (torch.Size([4, 1024]), torch.Size([4, 34]))
# Test size is 6000
# 21:07:09.181506
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 77.343750 %
# Completed 256/6000  4.266667 %
# Total correct predicted number is 198 out of 256
# 21:07:09.560145
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 76.171875 %
# Completed 512/6000  8.533333 %
# Total correct predicted number is 195 out of 256
# 21:07:09.938767
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 77.734375 %
# Completed 768/6000  12.800000 %
# Total correct predicted number is 199 out of 256
# 21:07:10.310159
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.656250 %
# Completed 1024/6000  17.066667 %
# Total correct predicted number is 186 out of 256
# 21:07:10.690526
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 68.750000 %
# Completed 1280/6000  21.333333 %
# Total correct predicted number is 176 out of 256
# 21:07:11.071115
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.000000 %
# Completed 1536/6000  25.600000 %
# Total correct predicted number is 192 out of 256
# 21:07:11.453076
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.875000 %
# Completed 1792/6000  29.866667 %
# Total correct predicted number is 184 out of 256
# 21:07:11.828315
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 70.703125 %
# Completed 2048/6000  34.133333 %
# Total correct predicted number is 181 out of 256
# 21:07:12.200176
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 70.312500 %
# Completed 2304/6000  38.400000 %
# Total correct predicted number is 180 out of 256
# 21:07:12.580587
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.656250 %
# Completed 2560/6000  42.666667 %
# Total correct predicted number is 186 out of 256
# 21:07:12.956185
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 74.609375 %
# Completed 2816/6000  46.933333 %
# Total correct predicted number is 191 out of 256
# 21:07:13.332522
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.390625 %
# Completed 3072/6000  51.200000 %
# Total correct predicted number is 193 out of 256
# 21:07:13.708645
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.265625 %
# Completed 3328/6000  55.466667 %
# Total correct predicted number is 185 out of 256
# 21:07:14.087748
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 74.218750 %
# Completed 3584/6000  59.733333 %
# Total correct predicted number is 190 out of 256
# 21:07:14.468557
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.093750 %
# Completed 3840/6000  64.000000 %
# Total correct predicted number is 182 out of 256
# 21:07:14.845715
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 79.296875 %
# Completed 4096/6000  68.266667 %
# Total correct predicted number is 203 out of 256
# 21:07:15.225950
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 74.218750 %
# Completed 4352/6000  72.533333 %
# Total correct predicted number is 190 out of 256
# 21:07:15.602924
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.265625 %
# Completed 4608/6000  76.800000 %
# Total correct predicted number is 185 out of 256
# 21:07:15.982456
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 74.609375 %
# Completed 4864/6000  81.066667 %
# Total correct predicted number is 191 out of 256
# 21:07:16.362651
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 72.265625 %
# Completed 5120/6000  85.333333 %
# Total correct predicted number is 185 out of 256
# 21:07:16.742010
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 75.781250 %
# Completed 5376/6000  89.600000 %
# Total correct predicted number is 194 out of 256
# 21:07:17.120393
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 69.921875 %
# Completed 5632/6000  93.866667 %
# Total correct predicted number is 179 out of 256
# 21:07:17.501097
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([256, 1024]), torch.Size([256, 34]))
# This batch accuracy is 71.093750 %
# Completed 5888/6000  98.133333 %
# Total correct predicted number is 182 out of 256
# 21:07:17.675456
# Time for testing passed 0 minutes and 0 seconds
# (torch.Size([112, 1024]), torch.Size([112, 34]))
# This batch accuracy is 70.535714 %
# Completed 6144/6000  102.400000 %
# Total correct predicted number is 79 out of 256

# %%
# (error, accuracy) = test_model(net, test_ftrs, test_gz)
(accuracy) = test.test_model(optimizer,net, test_face_landmarks_dataset, 32)


print('Total accuracies:' )
print(accuracies)

# %%
# torch.save(net.state_dict(), 'new_multi_modal_model.py')

# %%
# net = MultiModalNetwork().cuda()

# for param in net.landmarkUnit.parameters():
#     param.requires_grad = False
# net.load_state_dict(torch.load('multi_modal_model.py'))
# # model.eval()
